# %%
import skimage.external.tifffile as tiff
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.utils.data as dataf
import torch.nn as nn

# %% [markdown]
# ### Hyperparameters
#
# ##### Data
# - Padding (if and how)
# - Patch size
#
# ##### Model
# - Filter size
# - Dropout
# - Activation
# - Layers (?)
# - Optimization
# - Loss

# %% [markdown]
# ## Data

# %%
Data = tiff.imread('data/CASI_SC_tif.tif')
TsLabel = tiff.imread('data/Test_sample.tif')
TrLabel = tiff.imread('data/Train_samples.tif')

# %%
patchsize = 16  # input spatial size for 2D-CNN
batchsize = 128  # select from [16, 32, 64, 128], the best is 64
EPOCH = 200
LR = 0.001

# %%
[l, m, n] = np.shape(Data)

# %%
x = Data

# boundary interpolation
temp = x[0,:,:]
pad_width = np.floor(patchsize/2)
pad_width = np.int(pad_width)
temp2 = np.pad(temp, pad_width, 'symmetric') 
[m2,n2] = temp2.shape
x2 = np.empty((l, m2, n2), dtype='float32')

for i in range(l):
    temp = x[i,:,:]
    pad_width = np.floor(patchsize/2)
    pad_width = np.int(pad_width)
    temp2 = np.pad(temp, pad_width, 'symmetric')
    x2[i,:,:] = temp2

# %%
# TrainPatch

[ind1, ind2] = np.where(TrLabel != 0)
TrainNum = len(ind1)
TrainPatch = np.empty((TrainNum, l, patchsize, patchsize), dtype='float32')
TrainLabel = np.empty(TrainNum)
ind3 = ind1 + pad_width
ind4 = ind2 + pad_width
for i in range(len(ind1)):
    patch = x2[:,(ind3[i] - pad_width):(ind3[i] + pad_width), (ind4[i] - pad_width):(ind4[i] + pad_width)]
    patch = np.reshape(patch, (patchsize * patchsize, l))
    patch = np.transpose(patch)
    patch = np.reshape(patch, (l, patchsize, patchsize))
    TrainPatch[i, :, :, :] = patch
    patchlabel = TrLabel[ind1[i], ind2[i]]
    TrainLabel[i] = patchlabel

# %%
# TestPatch

[ind1, ind2] = np.where(TsLabel != 0)
TestNum = len(ind1)
TestPatch = np.empty((TestNum, l, patchsize, patchsize), dtype='float32')
TestLabel = np.empty(TestNum)
ind3 = ind1 + pad_width
ind4 = ind2 + pad_width
for i in range(len(ind1)):
    patch = x2[:, (ind3[i] - pad_width):(ind3[i] + pad_width), (ind4[i] - pad_width):(ind4[i] + pad_width)]
    patch = np.reshape(patch, (patchsize * patchsize, l))
    patch = np.transpose(patch)
    patch = np.reshape(patch, (l, patchsize, patchsize))
    TestPatch[i, :, :, :] = patch
    patchlabel = TsLabel[ind1[i], ind2[i]]
    TestLabel[i] = patchlabel

# %%
print('Training size and testing size are:', TrainPatch.shape, 'and', TestPatch.shape)
# Out:
# Training size and testing size are: (2832, 144, 16, 16) and (12197, 144, 16, 16)

# %%
TrainPatch = torch.from_numpy(TrainPatch)
TrainLabel = torch.from_numpy(TrainLabel)-1
TrainLabel = TrainLabel.long()
dataset = dataf.TensorDataset(TrainPatch, TrainLabel)
train_loader = dataf.DataLoader(dataset, batch_size=batchsize, shuffle=True)

TestPatch = torch.from_numpy(TestPatch)
TestLabel = torch.from_numpy(TestLabel)-1
TestLabel = TestLabel.long()

Classes = len(np.unique(TrainLabel))

OutChannel = 32

# %% [markdown]
# ## Model

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels = l,
                out_channels = OutChannel,
                kernel_size = 3,
                stride = 1,
                padding = 1,
            ),
            nn.BatchNorm2d(OutChannel),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(OutChannel, OutChannel*2, 3, 1, 1),
            nn.BatchNorm2d(OutChannel*2),
            nn.ReLU(),
            nn.MaxPool2d(2),
            # nn.Dropout(0.5),

        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(OutChannel*2, OutChannel*4, 3, 1, 1),
            nn.BatchNorm2d(OutChannel*4),
            nn.ReLU(),
            nn.AdaptiveMaxPool2d(1),
            # nn.Dropout(0.5),

        )

        self.out = nn.Linear(OutChannel*4, Classes)  # fully connected layer, output 16 classes

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = x.view(x.size(0), -1)  # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
        output = self.out(x)
        return output

# %%
cnn = CNN()
print('The structure of the designed network', cnn)

# move model to GPU
cnn.cuda()

optimizer = torch.optim.Adam(cnn.parameters(), lr=LR)  # optimize all cnn parameters
loss_func = nn.CrossEntropyLoss()  # the target label is not one-hotted
# Out:
# The structure of the designed network CNN(
#   (conv1): Sequential(
#     (0): Conv2d(144, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): AdaptiveMaxPool2d(output_size=1)
#   )
#   (out): Linear(in_features=128, out_features=15, bias=True)
# )

# %%
model_parameters = filter(lambda p: p.requires_grad, cnn.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print(params)
# Out:
# 136239

# %% [markdown]
# ## Training

# %%
BestAcc = 0
# train and test the designed model
for epoch in range(EPOCH):
    for step, (b_x, b_y) in enumerate(train_loader):  # gives batch data, normalize x when iterate train_loader

        # move train data to GPU
        b_x = b_x.cuda()
        b_y = b_y.cuda()
        output = cnn(b_x)  # cnn output
        loss = loss_func(output, b_y)  # cross entropy loss
        optimizer.zero_grad()  # clear gradients for this training step
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients

        if step % 50 == 0:
            cnn.eval()

            pred_y = np.empty((len(TestLabel)), dtype='float32')
            number = len(TestLabel) // 5000
            for i in range(number):
                temp = TestPatch[i * 5000:(i + 1) * 5000, :, :, :]
                temp = temp.cuda()
                temp2 = cnn(temp)
                temp3 = torch.max(temp2, 1)[1].squeeze()
                pred_y[i * 5000:(i + 1) * 5000] = temp3.cpu()
                del temp, temp2, temp3

            if (i + 1) * 5000 < len(TestLabel):
                temp = TestPatch[(i + 1) * 5000:len(TestLabel), :, :, :]
                temp = temp.cuda()
                temp2 = cnn(temp)
                temp3 = torch.max(temp2, 1)[1].squeeze()
                pred_y[(i + 1) * 5000:len(TestLabel)] = temp3.cpu()
                del temp, temp2, temp3

            pred_y = torch.from_numpy(pred_y).long()
            accuracy = torch.sum(pred_y == TestLabel).type(torch.FloatTensor) / TestLabel.size(0)
            # test_output = rnn(TestData)
            # pred_y = torch.max(test_output, 1)[1].cuda().data.squeeze()
            # accuracy = torch.sum(pred_y == TestDataLabel).type(torch.FloatTensor) / TestDataLabel.size(0)
            print('Epoch: ', epoch, '| train loss: %.4f' % loss.data.cpu().numpy(), '| test accuracy: %.2f' % accuracy)
            # save the parameters in network
            if accuracy > BestAcc:
                torch.save(cnn.state_dict(), 'net_params_2DCNN.pkl')
                BestAcc = accuracy

            cnn.train()
# Out:
# Epoch:  0 | train loss: 3.2318 | test accuracy: 0.15
# Epoch:  1 | train loss: 1.0955 | test accuracy: 0.38
# Epoch:  2 | train loss: 0.4114 | test accuracy: 0.57
# Epoch:  3 | train loss: 0.3129 | test accuracy: 0.59
# Epoch:  4 | train loss: 0.1499 | test accuracy: 0.67
# Epoch:  5 | train loss: 0.0635 | test accuracy: 0.66
# Epoch:  6 | train loss: 0.0841 | test accuracy: 0.59
# Epoch:  7 | train loss: 0.0668 | test accuracy: 0.68
# Epoch:  8 | train loss: 0.0583 | test accuracy: 0.49
# Epoch:  9 | train loss: 0.0449 | test accuracy: 0.59
# Epoch:  10 | train loss: 0.0140 | test accuracy: 0.72
# Epoch:  11 | train loss: 0.0109 | test accuracy: 0.72
# Epoch:  12 | train loss: 0.0136 | test accuracy: 0.73
# Epoch:  13 | train loss: 0.0074 | test accuracy: 0.77
# Epoch:  14 | train loss: 0.0116 | test accuracy: 0.63
# Epoch:  15 | train loss: 0.0172 | test accuracy: 0.54
# Epoch:  16 | train loss: 0.0149 | test accuracy: 0.74
# Epoch:  17 | train loss: 0.0133 | test accuracy: 0.78
# Epoch:  18 | train loss: 0.0033 | test accuracy: 0.77
# Epoch:  19 | train loss: 0.0026 | test accuracy: 0.79
# Epoch:  20 | train loss: 0.0021 | test accuracy: 0.76
# Epoch:  21 | train loss: 0.0019 | test accuracy: 0.79
# Epoch:  22 | train loss: 0.0038 | test accuracy: 0.60
# Epoch:  23 | train loss: 0.0120 | test accuracy: 0.69
# Epoch:  24 | train loss: 0.0029 | test accuracy: 0.76
# Epoch:  25 | train loss: 0.0030 | test accuracy: 0.78
# Epoch:  26 | train loss: 0.0011 | test accuracy: 0.78
# Epoch:  27 | train loss: 0.0012 | test accuracy: 0.79
# Epoch:  28 | train loss: 0.0010 | test accuracy: 0.78
# Epoch:  29 | train loss: 0.0011 | test accuracy: 0.79
# Epoch:  30 | train loss: 0.0009 | test accuracy: 0.78
# Epoch:  31 | train loss: 0.0015 | test accuracy: 0.78
# Epoch:  32 | train loss: 0.0011 | test accuracy: 0.78
# Epoch:  33 | train loss: 0.0008 | test accuracy: 0.79
# Epoch:  34 | train loss: 0.0012 | test accuracy: 0.74
# Epoch:  35 | train loss: 0.0055 | test accuracy: 0.77
# Epoch:  36 | train loss: 0.0017 | test accuracy: 0.79
# Epoch:  37 | train loss: 0.0006 | test accuracy: 0.78
# Epoch:  38 | train loss: 0.0740 | test accuracy: 0.77
# Epoch:  39 | train loss: 0.0046 | test accuracy: 0.72
# Epoch:  40 | train loss: 0.0070 | test accuracy: 0.72
# Epoch:  41 | train loss: 0.0019 | test accuracy: 0.55
# Epoch:  42 | train loss: 0.0025 | test accuracy: 0.69
# Epoch:  43 | train loss: 0.0384 | test accuracy: 0.67
# Epoch:  44 | train loss: 0.0033 | test accuracy: 0.73
# Epoch:  45 | train loss: 0.0009 | test accuracy: 0.78
# Epoch:  46 | train loss: 0.0026 | test accuracy: 0.51
# Epoch:  47 | train loss: 0.0403 | test accuracy: 0.40
# Epoch:  48 | train loss: 0.0071 | test accuracy: 0.65
# Epoch:  49 | train loss: 0.0035 | test accuracy: 0.74
# Epoch:  50 | train loss: 0.0019 | test accuracy: 0.77
# Epoch:  51 | train loss: 0.0009 | test accuracy: 0.79
# Epoch:  52 | train loss: 0.0007 | test accuracy: 0.79
# Epoch:  53 | train loss: 0.0005 | test accuracy: 0.80
# Epoch:  54 | train loss: 0.0006 | test accuracy: 0.78
# Epoch:  55 | train loss: 0.0005 | test accuracy: 0.80
# Epoch:  56 | train loss: 0.0006 | test accuracy: 0.78
# Epoch:  57 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  58 | train loss: 0.0004 | test accuracy: 0.79
# Epoch:  59 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  60 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  61 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  62 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  63 | train loss: 0.0119 | test accuracy: 0.50
# Epoch:  64 | train loss: 0.0089 | test accuracy: 0.55
# Epoch:  65 | train loss: 0.0032 | test accuracy: 0.75
# Epoch:  66 | train loss: 0.0021 | test accuracy: 0.73
# Epoch:  67 | train loss: 0.0008 | test accuracy: 0.80
# Epoch:  68 | train loss: 0.0004 | test accuracy: 0.80
# Epoch:  69 | train loss: 0.0004 | test accuracy: 0.80
# Epoch:  70 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  71 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  72 | train loss: 0.0002 | test accuracy: 0.81
# Epoch:  73 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  74 | train loss: 0.0003 | test accuracy: 0.79
# Epoch:  75 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  76 | train loss: 0.0002 | test accuracy: 0.78
# Epoch:  77 | train loss: 0.0014 | test accuracy: 0.24
# Epoch:  78 | train loss: 0.0121 | test accuracy: 0.62
# Epoch:  79 | train loss: 0.0030 | test accuracy: 0.74
# Epoch:  80 | train loss: 0.0011 | test accuracy: 0.77
# Epoch:  81 | train loss: 0.0061 | test accuracy: 0.55
# Epoch:  82 | train loss: 0.0153 | test accuracy: 0.75
# Epoch:  83 | train loss: 0.0046 | test accuracy: 0.70
# Epoch:  84 | train loss: 0.0009 | test accuracy: 0.78
# Epoch:  85 | train loss: 0.0005 | test accuracy: 0.79
# Epoch:  86 | train loss: 0.0003 | test accuracy: 0.79
# Epoch:  87 | train loss: 0.0005 | test accuracy: 0.79
# Epoch:  88 | train loss: 0.0003 | test accuracy: 0.79
# Epoch:  89 | train loss: 0.0006 | test accuracy: 0.79
# Epoch:  90 | train loss: 0.0004 | test accuracy: 0.78
# Epoch:  91 | train loss: 0.0003 | test accuracy: 0.78
# Epoch:  92 | train loss: 0.0002 | test accuracy: 0.77
# Epoch:  93 | train loss: 0.0003 | test accuracy: 0.77
# Epoch:  94 | train loss: 0.0002 | test accuracy: 0.78
# Epoch:  95 | train loss: 0.0002 | test accuracy: 0.79
# Epoch:  96 | train loss: 0.0003 | test accuracy: 0.68
# Epoch:  97 | train loss: 0.0046 | test accuracy: 0.69
# Epoch:  98 | train loss: 0.0016 | test accuracy: 0.73
# Epoch:  99 | train loss: 0.0011 | test accuracy: 0.70
# Epoch:  100 | train loss: 0.0012 | test accuracy: 0.74
# Epoch:  101 | train loss: 0.0005 | test accuracy: 0.79
# Epoch:  102 | train loss: 0.0004 | test accuracy: 0.79
# Epoch:  103 | train loss: 0.0011 | test accuracy: 0.62
# Epoch:  104 | train loss: 0.0116 | test accuracy: 0.55
# Epoch:  105 | train loss: 0.0315 | test accuracy: 0.46
# Epoch:  106 | train loss: 0.0222 | test accuracy: 0.77
# Epoch:  107 | train loss: 0.0024 | test accuracy: 0.72
# Epoch:  108 | train loss: 0.0010 | test accuracy: 0.79
# Epoch:  109 | train loss: 0.0006 | test accuracy: 0.77
# Epoch:  110 | train loss: 0.0057 | test accuracy: 0.47
# Epoch:  111 | train loss: 0.0098 | test accuracy: 0.59
# Epoch:  112 | train loss: 0.0012 | test accuracy: 0.65
# Epoch:  113 | train loss: 0.0174 | test accuracy: 0.61
# Epoch:  114 | train loss: 0.0022 | test accuracy: 0.79
# Epoch:  115 | train loss: 0.0011 | test accuracy: 0.79
# Epoch:  116 | train loss: 0.0009 | test accuracy: 0.79
# Epoch:  117 | train loss: 0.0007 | test accuracy: 0.78
# Epoch:  118 | train loss: 0.0019 | test accuracy: 0.76
# Epoch:  119 | train loss: 0.0006 | test accuracy: 0.80
# Epoch:  120 | train loss: 0.0007 | test accuracy: 0.80
# Epoch:  121 | train loss: 0.0005 | test accuracy: 0.79
# Epoch:  122 | train loss: 0.0009 | test accuracy: 0.78
# Epoch:  123 | train loss: 0.0006 | test accuracy: 0.81
# Epoch:  124 | train loss: 0.0003 | test accuracy: 0.79
# Epoch:  125 | train loss: 0.0004 | test accuracy: 0.79
# Epoch:  126 | train loss: 0.0004 | test accuracy: 0.80
# Epoch:  127 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  128 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  129 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  130 | train loss: 0.0002 | test accuracy: 0.79
# Epoch:  131 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  132 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  133 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  134 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  135 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  136 | train loss: 0.0003 | test accuracy: 0.80
# Epoch:  137 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  138 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  139 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  140 | train loss: 0.0002 | test accuracy: 0.79
# Epoch:  141 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  142 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  143 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  144 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  145 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  146 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  147 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  148 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  149 | train loss: 0.0001 | test accuracy: 0.74
# Epoch:  150 | train loss: 0.0020 | test accuracy: 0.71
# Epoch:  151 | train loss: 0.0009 | test accuracy: 0.77
# Epoch:  152 | train loss: 0.0005 | test accuracy: 0.82
# Epoch:  153 | train loss: 0.0002 | test accuracy: 0.80
# Epoch:  154 | train loss: 0.0002 | test accuracy: 0.81
# Epoch:  155 | train loss: 0.0002 | test accuracy: 0.82
# Epoch:  156 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  157 | train loss: 0.0002 | test accuracy: 0.82
# Epoch:  158 | train loss: 0.0002 | test accuracy: 0.82
# Epoch:  159 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  160 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  161 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  162 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  163 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  164 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  165 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  166 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  167 | train loss: 0.0002 | test accuracy: 0.81
# Epoch:  168 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  169 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  170 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  171 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  172 | train loss: 0.0002 | test accuracy: 0.82
# Epoch:  173 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  174 | train loss: 0.0004 | test accuracy: 0.82
# Epoch:  175 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  176 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  177 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  178 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  179 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  180 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  181 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  182 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  183 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  184 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  185 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  186 | train loss: 0.0001 | test accuracy: 0.82
# Epoch:  187 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  188 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  189 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  190 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  191 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  192 | train loss: 0.0000 | test accuracy: 0.82
# Epoch:  193 | train loss: 0.0001 | test accuracy: 0.81
# Epoch:  194 | train loss: 0.0001 | test accuracy: 0.80
# Epoch:  195 | train loss: 0.0059 | test accuracy: 0.77
# Epoch:  196 | train loss: 0.1153 | test accuracy: 0.61
# Epoch:  197 | train loss: 0.0087 | test accuracy: 0.59
# Epoch:  198 | train loss: 0.0053 | test accuracy: 0.58
# Epoch:  199 | train loss: 0.0064 | test accuracy: 0.76

# %% [markdown]
# ## Evaluation

# %%
cnn.load_state_dict(torch.load('net_params_2DCNN.pkl'))
cnn.eval()
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(144, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): AdaptiveMaxPool2d(output_size=1)
#   )
#   (out): Linear(in_features=128, out_features=15, bias=True)
# )

# %%
pred_y = np.empty((len(TestLabel)), dtype='float32')
number = len(TestLabel)//5000
for i in range(number):
    temp = TestPatch[i*5000:(i+1)*5000, :, :]
    temp = temp.cuda()
    temp2 = cnn(temp)
    temp3 = torch.max(temp2, 1)[1].squeeze()
    pred_y[i*5000:(i+1)*5000] = temp3.cpu()
    del temp, temp2, temp3

if (i+1)*5000 < len(TestLabel):
    temp = TestPatch[(i+1)*5000:len(TestLabel), :, :]
    temp = temp.cuda()
    temp2 = cnn(temp)
    temp3 = torch.max(temp2, 1)[1].squeeze()
    pred_y[(i+1)*5000:len(TestLabel)] = temp3.cpu()
    del temp, temp2, temp3

pred_y = torch.from_numpy(pred_y).long()
OA = torch.sum(pred_y == TestLabel).type(torch.FloatTensor) / TestLabel.size(0)

Classes = np.unique(TestLabel)
EachAcc = np.empty(len(Classes))

for i in range(len(Classes)):
    cla = Classes[i]
    right = 0
    sum = 0

    for j in range(len(TestLabel)):
        if TestLabel[j] == cla:
            sum += 1
        if TestLabel[j] == cla and pred_y[j] == cla:
            right += 1

    EachAcc[i] = right.__float__()/sum.__float__()


print(OA)
print(EachAcc)
# Out:
# tensor(0.8230)
# [0.79202279 0.97650376 0.62376238 0.91287879 0.94223485 0.79020979
#  0.89365672 0.6951567  0.8470255  0.77413127 0.75806452 0.87704131
#  0.58947368 0.92307692 0.59408034]

# %% [markdown]
# ## Prediction

# %%
part = 5000
pred_all = np.empty((m*n, 1), dtype='float32')

number = m*n//part
for i in range(number):
    D = np.empty((part, l, patchsize, patchsize), dtype='float32')
    count = 0
    for j in range(i*part, (i+1)*part):
        row = j//n
        col = j - row*n
        row2 = row + pad_width
        col2 = col + pad_width
        patch = x2[:, (row2 - pad_width):(row2 + pad_width), (col2 - pad_width):(col2 + pad_width)]
        patch = np.reshape(patch, (patchsize * patchsize, l))
        patch = np.transpose(patch)
        patch = np.reshape(patch, (l, patchsize, patchsize))
        D[count, :, :, :] = patch
        count += 1

    temp = torch.from_numpy(D)
    temp = temp.cuda()
    temp2 = cnn(temp)
    temp3 = torch.max(temp2, 1)[1].squeeze()
    pred_all[i*part:(i+1)*part, 0] = temp3.cpu()
    del temp, temp2, temp3, D

if (i+1)*part < m*n:
    D = np.empty((m*n-(i+1)*part, l, patchsize, patchsize), dtype='float32')
    count = 0
    for j in range((i+1)*part, m*n):
        row = j // n
        col = j - row * n
        row2 = row + pad_width
        col2 = col + pad_width
        patch = x2[:, (row2 - pad_width):(row2 + pad_width), (col2 - pad_width):(col2 + pad_width)]
        patch = np.reshape(patch, (patchsize * patchsize, l))
        patch = np.transpose(patch)
        patch = np.reshape(patch, (l, patchsize, patchsize))
        D[count, :, :, :] = patch
        count += 1

    temp = torch.from_numpy(D)
    temp = temp.cuda()
    temp2 = cnn(temp)
    temp3 = torch.max(temp2, 1)[1].squeeze()
    pred_all[(i + 1) * part:m*n, 0] = temp3.cpu()
    del temp, temp2, temp3, D


pred_all = np.reshape(pred_all, (m, n)) + 1
OA = OA.numpy()
pred_y = pred_y.cpu()
pred_y = pred_y.numpy()
TestDataLabel = TestLabel.cpu()
TestDataLabel = TestDataLabel.numpy()

# %%
tiff.imsave('pred_cnn.tif', pred_all)
# pred_all = tiff.imread('pred_cnn.tif')

# %%
plt.figure(figsize=(40,40))
plt.imshow(pred_all)
plt.show()
